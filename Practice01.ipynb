# %%
print("Welcome Home!")
a = "WOW"
print("Welcome Home!" + a*3)
print(1+6)
# Out:
# Welcome Home!
# Welcome Home!WOWWOWWOW
# 7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.linspace(-10 , 10, 100)
y = np.sin(x) 
plt.plot(x, y, marker="x")
plt.show()

p = np.linspace(0,50,100)
plt.plot(p,np.sin(15*p))
plt.show()

import seaborn as sns
sns.set()

p = np.linspace(0,50,20)
plt.plot(p,np.sin(25*p))
plt.show()

p = np.linspace(0,800,20)
plt.plot(p,np.sin(15*p))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7deef36f3470> in <module>
#      12 plt.show()
#      13
# ---> 14 import seaborn as sns
#      15 sns.set()
#      16
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import folium
WIP_location = [13.652805, 100.493638]
WIP_Camp = folium.Map(location = WIP_location, zoom_start=16)
WIP = folium.map.FeatureGroup()
WIP.add_child(folium.CircleMarker([13.652805, 100.493638], radius = 30, color = "blue", fill_color = "Red"))
WIP_Camp.add_child(WIP)
folium.Marker([13.652805, 100.493638], popup = "WIP Camp").add_to(WIP_Camp)
WIP_Camp

# %%
def e(n):
    for x in range(n):
        print(x+1,"\tI love XXX")

e(30)
